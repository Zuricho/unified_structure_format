# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# INPUT
FILE_PATH = "example/6zk6.usf"
FILE_NAME = "6zk6"

# %%
usf_dict = pickle.load(open(FILE_PATH, "rb"))

# %%
# 3D visualization of atom coordiates
plt.figure(figsize=(10, 10))
plt.subplot(111, projection='3d')
plt.scatter(usf_dict["coordinate"][:,0], usf_dict["coordinate"][:,1], usf_dict["coordinate"][:,2], c='r', marker='o')
